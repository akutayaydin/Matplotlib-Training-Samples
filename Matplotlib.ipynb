# %% [markdown]
# <a href="https://colab.research.google.com/github/akutayaydin/Training-/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,4])
plt.show()

# %%
plt.plot([2,4])
a = plt.gcf() # get current figure

# %%
type(a)
# Out:
# matplotlib.figure.Figure

# %%
type(a.axes)
# Out:
# list

# %%
b = a.axes[0]

# %%
b.set
# Out:
# <bound method Axes.set of <Axes: >>

# %%
b.set_ylabel('test')
# Out:
# Text(4.444444444444452, 0.5, 'test')

# %%
a.get_facecolor()
# Out:
# (1.0, 1.0, 1.0, 1.0)

# %%
a.set_facecolor('r')

# %%
a

# %%
plt.subplots(2,2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
whos
# Out:
# Variable     Type      Data/Info
# --------------------------------
# a            Figure    Figure(640x480)
# b            Axes      Axes(0.125,0.11;0.775x0.77)
# matplotlib   module    <module 'matplotlib' from<...>/matplotlib/__init__.py'>
# plt          module    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>

# %%
import numpy as np

x = np.arange(1,10)

y = x*2

z = y*2

# %%
plt.plot(x,y)
plt.plot(x,z)
c = plt.gcf()

# %%
#%matplotlib notebook # makes matplotlib graph interactive

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x = np.arange(1,11)
y =  ([500,400,600,800,1000,1200,1400,1600,1800,2000])

# %%
'''
# %d: Format as a decimal integer.
# %f: Format as a floating-point number.
# %.2f: Format as a floating-point number with 2 decimal places (you can adjust the number of decimal places).
# %s: Format as a string.
# %x: Format as a hexadecimal integer.
# %o: Format as an octal integer.
'''
# Out:
# '\n%d: Format as a decimal integer.\n%f: Format as a floating-point number.\n%.2f: Format as a floating-point number with 2 decimal places (you can adjust the number of decimal places).\n%s: Format as a string.\n%x: Format as a hexadecimal integer.\n%o: Format as an octal integer.\n'

# %%
import calendar

fig, ax = plt.subplots()
plot = ax.bar(x,y)
plt.xticks(x,calendar.month_name[1:11],rotation =40, fontsize=10)

for rect in plot:
  height = rect.get_height()
  plt.text (rect.get_x() + rect.get_width()/2, 1.002*height,'%d' % int(height),ha = 'center',va = 'bottom', color ='r' )

ax.bar_label(plot,labels=['label1','label2'],label_type ='center')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data with multiple features
np.random.seed(0)
n_features = 5
data = np.random.rand(100, n_features)  # 100 samples and 5 features

# Calculate the correlation matrix
correlation_matrix = np.corrcoef(data, rowvar=False)

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Correlation', shrink=0.8, aspect=10)
plt.xticks(np.arange(n_features), [f'Feature {i+1}' for i in range(n_features)], rotation=45)
plt.yticks(np.arange(n_features), [f'Feature {i+1}' for i in range(n_features)])
plt.title('Correlation Heatmap for Multiple Features')
plt.show()

# %%
plt.plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-74681711b19f> in <cell line: 9>()
#       7 import matplotlib.pyplot as plt
#       8
# ----> 9 from util import getKaggleMNIST
#      10 from keras.models import Model
#      11 from keras.layers import Dense, Activation, Input
#
# ModuleNotFoundError: No module named 'util'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
